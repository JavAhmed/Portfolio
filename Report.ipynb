# %%
# Import pandas
import pandas as pd

# %%
# Create a DataFrame with balance.txt
df = pd.read_csv('balance.txt', delim_whitespace=True)
# Out:
# C:\Users\javah\AppData\Local\Temp\ipykernel_14592\3555762267.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv('balance.txt', delim_whitespace=True)

# %% [markdown]
# Write the code needed to produce a report that provides the following information:
# * Compare the average income based on ethnicity.
# * On average, do married or single people have a higher balance?
# * What is the highest income in our dataset?
# * What is the lowest income in our dataset?
# * How many cards do we have recorded in our dataset? (Hint: use `sum()`)
# * How many females do we have information for vs how many males? (Hint: use `count()` for a list of all methods for computation of descriptive stats, explore the [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html#computations-descriptive-stats)).

# %%
# Compare the average income based on ethnicity.
print("Average income based on ethnicity:")
print(df.groupby('Ethnicity')['Income'].mean())

# On average, do married or single people have a higher balance?
print("\nAverage balance based on marital status:")
print(df.groupby('Married')['Balance'].mean())

# What is the highest income in our dataset?
print("\nHighest income:")
print(df['Income'].max())

# What is the lowest income in our dataset?
print("Lowest income:")
print(df['Income'].min())

# How many cards do we have recorded in our dataset?
print("\nNumber of cards:")
print(df['Cards'].sum())

# How many females do we have information for vs how many males?
print("\nNumber of females vs males:")
print(df['Gender'].value_counts())
# Out:
# Average income based on ethnicity:
# Ethnicity
# African American    47.682101
# Asian               44.187833
# Caucasian           44.521945
# Name: Income, dtype: float64
#
# Average balance based on marital status:
# Married
# No     13.493509
# Yes    13.388473
# Name: Balance, dtype: float64
#
# Highest income:
# 186.634
# Lowest income:
# 10.354
#
# Number of cards:
# 1183
#
# Number of females vs males:
# Gender
# Female    207
# Male      193
# Name: count, dtype: int64
